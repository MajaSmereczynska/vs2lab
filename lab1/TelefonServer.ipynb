# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# 2025-10-27 12:08:09,775 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=57, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2025-10-27 12:08:25,169 - vs2lab.lab1.clientserver.Server - INFO - Connection accepted from ('127.0.0.1', 53156)
# 2025-10-27 12:08:25,170 - vs2lab.lab1.clientserver.Server - INFO - Received data: GET:Alpha
# 2025-10-27 12:08:25,176 - vs2lab.lab1.clientserver.Server - INFO - Received data: GETALL

# %% [markdown]
# Finished
